# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Vikasbit/flyrank-content-refresh-prioritization/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("""
## My Lane as an ML Task

Task Type: Classification

My lane focuses on Content Refresh Prioritization.

This is a classification problem because the model predicts whether a webpage should be refreshed based on SEO and content signals.

Output:
- 1 = Refresh the page
- 0 = No refresh needed
""")
# Out:
# ## My Lane as an ML Task
#
# Task Type: Classification
#
# My lane focuses on Content Refresh Prioritization.
#
# This is a classification problem because the model predicts whether a webpage should be refreshed based on SEO and content signals.
#
# Output:
# - 1 = Refresh the page
# - 0 = No refresh needed

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
target = "needs_refresh"

target_description = """
Target values:
1 = Refresh required
0 = No refresh required

If labels are unavailable, a proxy target can be created using historical SEO performance such as declining clicks, impressions, or rankings.
"""

print("Target:", target)
print(target_description)
# Out:
# Target: needs_refresh
#
# Target values:
# 1 = Refresh required
# 0 = No refresh required
#
# If labels are unavailable, a proxy target can be created using historical SEO performance such as declining clicks, impressions, or rankings.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
success_metric = "F1 Score"

print("Primary Metric:", success_metric)
print("Secondary Metrics:")
print("- Precision")
print("- Recall")
# Out:
# Primary Metric: F1 Score
# Secondary Metrics:
# - Precision
# - Recall

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
print("Unit of Analysis:")
print("One row represents one webpage.")
print("Each row contains SEO and content-related features used for prediction.")
# Out:
# Unit of Analysis:
# One row represents one webpage.
# Each row contains SEO and content-related features used for prediction.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
reason = """
A fixed rule such as 'Refresh every page older than six months'
cannot capture the relationship between multiple SEO signals.

Machine learning can learn patterns from clicks, impressions,
CTR, rankings, and content quality to prioritize pages more accurately.
"""

print(reason)
# Out:
# A fixed rule such as 'Refresh every page older than six months'
# cannot capture the relationship between multiple SEO signals.
#
# Machine learning can learn patterns from clicks, impressions,
# CTR, rankings, and content quality to prioritize pages more accurately.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
